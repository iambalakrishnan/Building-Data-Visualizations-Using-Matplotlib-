# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
austin_weather = pd.read_csv('austin_weather.csv')
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
austin_weather.shape
# Out:
# (1319, 21)

# %%
#Lets trim our dataset only including required columns also limits data only for 30 rows

austin_weather = austin_weather[['Date','TempAvgF','WindAvgMPH']].head(30)

# %%
austin_weather
# Out:
#           Date  TempAvgF WindAvgMPH
# 0   2013-12-21        60          4
# 1   2013-12-22        48          6
# 2   2013-12-23        45          3
# 3   2013-12-24        46          4
# 4   2013-12-25        50          2
# 5   2013-12-26        48          3
# 6   2013-12-27        53          1
# 7   2013-12-28        51          2
# 8   2013-12-29        50          5
# 9   2013-12-30        40          5
# 10  2013-12-31        46          1
# 11  2014-01-01        54          4
# 12  2014-01-02        44          8
# 13  2014-01-03        43          4
# 14  2014-01-04        57          7
# 15  2014-01-05        47         10
# 16  2014-01-06        29          7
# 17  2014-01-07        35          5
# 18  2014-01-08        47          1
# 19  2014-01-09        62          3
# 20  2014-01-10        65          6
# 21  2014-01-11        62          3
# 22  2014-01-12        57          4
# 23  2014-01-13        57          7
# 24  2014-01-14        57          5
# ...

# %%
#Lets build twin axes plot with incremental fashon 

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

# %%
#Lets build twin axes plot with incremental fashon 

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

#Setting up x label
ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', bottom =  False, labelbottom = False)

#y labels 

ax_tempF.set_ylabel('Temp(F)', color = 'red', size = 'x-large')
ax_tempF.tick_params(axis = 'y', labelcolor = 'red', labelsize = 'x-large')

# %%
#Lets build twin axes plot with incremental fashon 

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

#Setting up x label
ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', bottom =  False, labelbottom = False)

#y labels 

ax_tempF.set_ylabel('Temp(F)', color = 'red', size = 'x-large')
ax_tempF.tick_params(axis = 'y', labelcolor = 'red', labelsize = 'x-large') 

#Avg temp per day in austin 
ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color = 'b')

# %%
#Lets build twin axes plot with incremental fashon 

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

#Setting up x label
ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', bottom =  False, labelbottom = False)

#y labels 

ax_tempF.set_ylabel('Temp(F)', color = 'red', size = 'x-large')
ax_tempF.tick_params(axis = 'y', labelcolor = 'red', labelsize = 'x-large') 

#Avg temp per day in austin 
ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color = 'b')

#The twinx() creates another Y axis using the same X axis
ax_wind = ax_tempF.twinx()#range is 0 to 1 we because we didn't explicitly defined value

# %%
#Lets build twin axes plot with incremental fashon 

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

#Setting up x label
ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', bottom =  False, labelbottom = False)

#y labels 

ax_tempF.set_ylabel('Temp(F)', color = 'red', size = 'x-large')
ax_tempF.tick_params(axis = 'y', labelcolor = 'red', labelsize = 'x-large') 

#Avg temp per day in austin 
ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color = 'b')

#The twinx() creates another Y axis using the same X axis
ax_wind = ax_tempF.twinx()#range is 0 to 1 we because we didn't explicitly defined value

ax_wind.set_ylabel('Avg  wind Speed(MPH)', color ='blue', size='x-large')

ax_wind.tick_params( axis='y', labelcolor='blue', labelsize='large')

# %%
# Lets plot avg windspeed data

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

#Setting up x label
ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', bottom =  False, labelbottom = False)

#y labels 

ax_tempF.set_ylabel('Temp(F)', color = 'red', size = 'x-large')
ax_tempF.tick_params(axis = 'y', labelcolor = 'red', labelsize = 'x-large') 

#Avg temp per day in austin 
ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color = 'red')

#The twinx() creates another Y axis using the same X axis
ax_wind = ax_tempF.twinx()#range is 0 to 1 we because we didn't explicitly defined value

ax_wind.set_ylabel('Avg  wind Speed(MPH)', color ='blue', size='x-large')

ax_wind.tick_params( axis='y', labelcolor='blue', labelsize='large')

ax_wind.plot(austin_weather['Date'], austin_weather['WindAvgMPH'], color='blue')

# %% [markdown]
# Twin axes can be used to represent same data in different units. Tos show temperature in fahrenheit and celsius, we define this conversion function

# %%
def fahrenheit2celsius(f):
    return (f - 32)*5/9

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis='x', bottom = False, labelbottom = False)

ax_tempF.set_ylabel('Temp(F)', color='red', size='x-large')
ax_tempF.tick_params(axis='y', labelcolor='red', labelsize='x-large')

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color='green')

ax_tempC = ax_tempF.twinx()#Twin axes to display weather in Celsius

#We get the range of the first y axis- this will be used to set the range of the new Y axis 
ymin, ymax = ax_tempF.get_ylim()

#set the limits for the celsius axis by conveting the fahrenheit axis limits to celsius

ax_tempC.set_ylim((fahrenheit2celsius(ymin),fahrenheit2celsius(ymax)))

ax_tempC.set_ylabel('Temp(C)', color='blue', size='x-large')
ax_tempC.tick_params(axis = 'y', labelcolor='blue', labelsize='large')
